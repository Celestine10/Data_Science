# %% [markdown]
# ![football.jpg](attachment:football.jpg)
# # SPORTS ANALYSIS: FOOTBALL PLAYERS
#
# ### This analysis would be concentrated around:-
# - ### Data Cleaning and Preprocessing
# - ### players and their corresponding skills and attributes that make them stand out.
# - ### players and their respective clubs and
# - ### players and their countries only.

# %% [markdown]
# ## Importing the Libraries we'll be using

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#Turning off the warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#To display all the columns of the dataframe
pd.set_option('display.max_columns',70)

# %%
#Reading the FIFA20 dataset
fifa = pd.read_csv("FIFA22_official_data.csv")

# %% [markdown]
# ## UNDERSTANDING THE DATA

# %%
#Dimension of the dataset
fifa.shape
# Out:
# (16710, 65)

# %% [markdown]
# 16710 datapoints or player details and 65 features/columns

# %%
#head of the dataset
fifa.head()
# Out:
#        ID             Name  Age  \
# 0  212198  Bruno Fernandes   26
# 1  209658      L. Goretzka   26
# 2  176580        L. Suárez   34
# 3  192985     K. De Bruyne   30
# 4  224334         M. Acuña   29
#
#                                               Photo Nationality  \
# 0  https://cdn.sofifa.com/players/212/198/22_60.png    Portugal
# 1  https://cdn.sofifa.com/players/209/658/22_60.png     Germany
# 2  https://cdn.sofifa.com/players/176/580/22_60.png     Uruguay
# 3  https://cdn.sofifa.com/players/192/985/22_60.png     Belgium
# 4  https://cdn.sofifa.com/players/224/334/22_60.png   Argentina
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.com/flags/pt.png       88         89
# 1  https://cdn.sofifa.com/flags/de.png       87         88
# 2  https://cdn.sofifa.com/flags/uy.png       88         88
# 3  https://cdn.sofifa.com/flags/be.png       91         91
# 4  https://cdn.sofifa.com/flags/ar.png       84         84
#
# ...

# %%
#columns of the dataframe
fifa.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'Crossing', 'Finishing', 'HeadingAccuracy',
#        'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
#        'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
#        'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
#        'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle',
#        'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
#        'Best Position', 'Best Overall Rating', 'Release Clause',
# ...

# %%
#INFO() function
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16710 entries, 0 to 16709
# Data columns (total 65 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        16710 non-null  int64
#  1   Name                      16710 non-null  object
#  2   Age                       16710 non-null  int64
#  3   Photo                     16710 non-null  object
#  4   Nationality               16710 non-null  object
#  5   Flag                      16710 non-null  object
#  6   Overall                   16710 non-null  int64
#  7   Potential                 16710 non-null  int64
#  8   Club                      16446 non-null  object
#  9   Club Logo                 16710 non-null  object
#  10  Value                     16710 non-null  object
#  11  Wage                      16710 non-null  object
#  12  Special                   16710 non-null  int64
# ...

# %%
fifa.isnull().sum().sort_values(ascending = False)
# Out:
# Marking               15818
# Loaned From           15578
# Release Clause         1749
# Joined                 1512
# DefensiveAwareness      892
#                       ...
# ShortPassing              0
# Name                      0
# FKAccuracy                0
# LongPassing               0
# Dribbling                 0
# Length: 65, dtype: int64

# %% [markdown]
# I can find there are some missing values for columns such as `Club,Joined`, `LoanedFrom`, `Release Clause`, `Marking`, `Joined`  and a few others.

# %%
#Some initial stats for the df
fifa.describe()
# Out:
#                   ID           Age       Overall     Potential       Special  \
# count   16710.000000  16710.000000  16710.000000  16710.000000  16710.000000
# mean   220560.467923     25.727409     67.646320     72.572292   1652.497307
# std     38496.607959      5.048910      6.457695      5.688085    257.271696
# min        27.000000     16.000000     28.000000     38.000000    571.000000
# 25%    203891.250000     22.000000     63.000000     69.000000   1525.000000
# 50%    229253.000000     25.000000     68.000000     72.000000   1687.000000
# 75%    245368.750000     29.000000     72.000000     76.000000   1826.000000
# max    264704.000000     54.000000     93.000000     95.000000   2341.000000
#
#        International Reputation     Weak Foot   Skill Moves  Jersey Number  \
# count              16710.000000  16710.000000  16710.000000   16684.000000
# mean                   1.169958      3.008199      2.475464      20.458643
# ...

# %%
#Copy of our pulled in df
fifa_copy = fifa.copy()

# %% [markdown]
# ## SOME CLEANING AND  PREPROCESSING

# %%
fifa.head()
# Out:
#        ID             Name  Age  \
# 0  212198  Bruno Fernandes   26
# 1  209658      L. Goretzka   26
# 2  176580        L. Suárez   34
# 3  192985     K. De Bruyne   30
# 4  224334         M. Acuña   29
#
#                                               Photo Nationality  \
# 0  https://cdn.sofifa.com/players/212/198/22_60.png    Portugal
# 1  https://cdn.sofifa.com/players/209/658/22_60.png     Germany
# 2  https://cdn.sofifa.com/players/176/580/22_60.png     Uruguay
# 3  https://cdn.sofifa.com/players/192/985/22_60.png     Belgium
# 4  https://cdn.sofifa.com/players/224/334/22_60.png   Argentina
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.com/flags/pt.png       88         89
# 1  https://cdn.sofifa.com/flags/de.png       87         88
# 2  https://cdn.sofifa.com/flags/uy.png       88         88
# 3  https://cdn.sofifa.com/flags/be.png       91         91
# 4  https://cdn.sofifa.com/flags/ar.png       84         84
#
# ...

# %% [markdown]
# - I am going to delete some `columns` which might not be adding any value adds to our analysis going forward.
# - All the url columns and index columns we will try removing right now.

# %%
#Dropping some of the columns - ID, Photo, Flag, Club Logo
fifa.drop(['ID','Photo','Flag','Club Logo'],axis=1,inplace=True)

# %%
#Dropping Real Face column
fifa.drop(['Real Face'],axis=1,inplace=True)

# %%
#Filtering for rows which have Loaned From column not NULL 
fifa.loc[~fifa['Loaned From'].isnull()][:5]
# Out:
#              Name  Age             Nationality  Overall  Potential  \
# 9    A. Griezmann   30                  France       85         85
# 43           Saúl   26                   Spain       82         85
# 72    A. Florenzi   30                   Italy       81         81
# 121     M. Pjanić   31  Bosnia and Herzegovina       82         82
# 155      J. Kucka   34                Slovakia       77         77
#
#                    Club   Value   Wage  Special Preferred Foot  \
# 9    Atlético de Madrid    €53M  €220K     2259           Left
# 43              Chelsea  €39.5M   €68K     2199           Left
# 72             AC Milan    €22M   €58K     2178          Right
# 121         Beşiktaş JK    €25M  €155K     2147          Right
# 155             Watford   €4.9M   €33K     2135          Right
#
#      International Reputation  Weak Foot  Skill Moves       Work Rate  \
# 9                         4.0        3.0          4.0  Medium/ Medium
# ...

# %% [markdown]
# You can find some of the Loaned players in the list above.<br>
# Players like Griezmann and Pjanic who are on loan from Barcelona to Atletico de Madrid and Besiktas respectively.

# %% [markdown]
# I guess it would be better in this case not to handle the missing values for the columns, because we might end up missing out so many players in that case.<br>
# For columns such as `Loaned From` might be many for so many players as well, since it would be a direct contract with the player.

# %% [markdown]
# - ### PLAYER VALUE AND WAGE
# - Checking whether all values are defined in Euros or not

# %%
fifa.loc[fifa['Value'].str.startswith('€')].shape[0]
# Out:
# 16710

# %% [markdown]
# ### Checking the same for Wages.

# %%
fifa.loc[fifa['Wage'].str.startswith('€')].shape[0]
# Out:
# 16710

# %% [markdown]
# So the Value and Wage of all the players are defined in Euros and also object type, which we can try converting accordingly and try making it as a numeric column.

# %%
#Splitting the value column to get just the numeric
fifa['Value'] = fifa['Value'].str.split('€')
fifa['Value'] = fifa['Value'].apply(lambda x:x[1])

# %%
#Splitting the wage column to get just the numeric
fifa['Wage'] = fifa['Wage'].str.split('€')
fifa['Wage'] = fifa['Wage'].apply(lambda x:x[1])

# %%
#Converting the player value in thousand Euros to Million Euros and then stripping the end denote.
fifa_value_K = fifa.loc[fifa['Value'].str.endswith('K')]
fifa_value_K['Value'] = fifa_value_K['Value'].apply(lambda x: x[:-1])
fifa_value_K['Value'] = fifa_value_K['Value'].astype('float64')
fifa_value_K['Value'] = fifa_value_K['Value'] / 1000

# %%
#Stripping the end denote for Million Euros Player value
fifa_value_M = fifa.loc[fifa['Value'].str.endswith('M')]
fifa_value_M['Value'] = fifa_value_M['Value'].apply(lambda x: x[:-1])
fifa_value_M['Value'] = fifa_value_M['Value'].astype('float64')

# %%
#Converting the player wage in thousand Euros to Million Euros and then stripping the end denote.
fifa_value_K['Wage'] = fifa_value_K['Wage'].apply(lambda x: x[:-1] if x.endswith('K') else x)
fifa_value_K['Wage'] = fifa_value_K['Wage'].astype('float64')
fifa_value_K['Wage'] = fifa_value_K['Wage'] / 1000

# %%
fifa_value_M.loc[fifa_value_M['Wage'].str.endswith("M")]
# Out:
# Empty DataFrame
# Columns: [Name, Age, Nationality, Overall, Potential, Club, Value, Wage, Special, Preferred Foot, International Reputation, Weak Foot, Skill Moves, Work Rate, Body Type, Position, Jersey Number, Joined, Loaned From, Contract Valid Until, Height, Weight, Crossing, Finishing, HeadingAccuracy, ShortPassing, Volleys, Dribbling, Curve, FKAccuracy, LongPassing, BallControl, Acceleration, SprintSpeed, Agility, Reactions, Balance, ShotPower, Jumping, Stamina, Strength, LongShots, Aggression, Interceptions, Positioning, Vision, Penalties, Composure, Marking, StandingTackle, SlidingTackle, GKDiving, GKHandling, GKKicking, GKPositioning, GKReflexes, Best Position, Best Overall Rating, Release Clause, DefensiveAwareness]
# Index: []

# %% [markdown]
# We can find that there are no more players who are having values and wages in euros having wages also in Millions. So we will go with thousand converted to millions

# %%
#Converting the player wage in thousand Euros to Million Euros and then stripping the end denote.
fifa_value_M['Wage'] = fifa_value_M['Wage'].apply(lambda x: x[:-1] if x.endswith('K') else x)
fifa_value_M['Wage'] = fifa_value_M['Wage'].astype('float64')
fifa_value_M['Wage'] = fifa_value_M['Wage'] / 1000

# %%
#Concatenating both the splitted up dataframes
fifa2 = pd.concat([fifa_value_M,fifa_value_K])

# %%
fifa2.shape
# Out:
# (16366, 60)

# %% [markdown]
# It looks like the resultant dataframe `fifa2` after our preprocessing, is having less number of records than our initial dataframe. These are records/rows that were having player Values provided as 0 or any other value which were neither in thousands nor Millions.
# We will proceed with this dataset forour analysis.

# %%
fifa2[fifa2['Value']==194]["Name"]
# Out:
# 82    K. Mbappé
# Name: Name, dtype: object

# %%
fifa2['Value'] = pd.to_numeric(fifa2['Value'])
fifa2['Wage'] = pd.to_numeric(fifa2['Wage'])

# %% [markdown]
# ### CLEANING THE POSITION FEATURE

# %% [markdown]
# We can find some HTML code getting in(probably when the data is scrapped) with the Position column. We will clean those.

# %%
fifa2['Position'] = fifa2['Position'].str.split(">")
fifa2['Position'] = fifa2['Position'].apply(lambda x:x[1])

# %%
fifa2.head()
# Out:
#               Name  Age Nationality  Overall  Potential                Club  \
# 0  Bruno Fernandes   26    Portugal       88         89   Manchester United
# 1      L. Goretzka   26     Germany       87         88   FC Bayern München
# 2        L. Suárez   34     Uruguay       88         88  Atlético de Madrid
# 3     K. De Bruyne   30     Belgium       91         91     Manchester City
# 4         M. Acuña   29   Argentina       84         84          Sevilla FC
#
#    Value   Wage  Special Preferred Foot  International Reputation  Weak Foot  \
# 0  107.5  0.250     2341          Right                       3.0        3.0
# 1   93.0  0.140     2314          Right                       4.0        4.0
# 2   44.5  0.135     2307          Right                       5.0        4.0
# 3  125.5  0.350     2304          Right                       4.0        5.0
# 4   37.0  0.045     2292           Left                       2.0        3.0
#
# ...

# %% [markdown]
# ### CLEANING THE WEIGHT COLUMN

# %% [markdown]
# All the player weights are mentioned in lbs and is object type. We will remove the suffixes and convert it into integer.

# %%
fifa2['Weight'] = fifa2['Weight'].apply(lambda x : x[:-3])
fifa2['Weight'] = fifa2['Weight'].astype('int64')

# %% [markdown]
# ## ANALYSIS ON THE PREFERED FOOT

# %%
foot = fifa2['Preferred Foot'].value_counts()
foot
# Out:
# Right    12352
# Left      4014
# Name: Preferred Foot, dtype: int64

# %% [markdown]
# As we expected, the Left Footers are fewer! there are only 4014 left footers in our player list.
#
# Let's check the percentage %

# %%
foot_right = foot[0]/fifa2['Preferred Foot'].count()*100
foot_left = foot[1]/fifa2['Preferred Foot'].count()*100
foot_df = pd.DataFrame({'Percentage':[foot_right,foot_left]},index=['Right Foot','Left Foot'])
foot_df.style.background_gradient(cmap='Purples')
# Out:
# <style type="text/css">
# #T_e7604_row0_col0 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_e7604_row1_col0 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_e7604_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7604_level0_row0" class="row_heading level0 row0" >Right Foot</th>
#       <td id="T_e7604_row0_col0" class="data row0 col0" >75.473543</td>
#     </tr>
#     <tr>
#       <th id="T_e7604_level0_row1" class="row_heading level0 row1" >Left Foot</th>
#       <td id="T_e7604_row1_col0" class="data row1 col0" >24.526457</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Barplot for the classes
plt.title("Foot Preference")
sns.barplot(x=foot_df.index,y=foot_df['Percentage'])
plt.show()

# %% [markdown]
# This clearly indicates the dominance of Right footers in the Football. There are just a small percentage of Left Footers, hence their importance.

# %% [markdown]
# ## AVERAGE AGE OF ALL THE PLAYERS

# %%
fifa2.Age.mean()
# Out:
# 25.633752902358548

# %% [markdown]
# ## The most used Jersey Number

# %%
plt.figure(figsize = (20, 6))
fifa2["Jersey Number"].value_counts().plot(kind='bar');

# %% [markdown]
# * **`Number 10` is the most worn number!!!**

# %% [markdown]
# ## TOP 5 MOST VALUABLE PLAYERS

# %%
fifa2.sort_values(['Value'],ascending=False)[:5]
# Out:
#              Name  Age Nationality  Overall  Potential                 Club  \
# 82      K. Mbappé   22      France       91         95  Paris Saint-Germain
# 251    E. Haaland   20      Norway       88         93    Borussia Dortmund
# 39        H. Kane   27     England       90         90    Tottenham Hotspur
# 64      Neymar Jr   29      Brazil       91         91  Paris Saint-Germain
# 3    K. De Bruyne   30     Belgium       91         91      Manchester City
#
#      Value  Wage  Special Preferred Foot  International Reputation  Weak Foot  \
# 82   194.0  0.23     2175          Right                       4.0        4.0
# 251  137.5  0.11     2102           Left                       4.0        3.0
# 39   129.5  0.24     2205          Right                       4.0        5.0
# 64   129.0  0.27     2183          Right                       5.0        5.0
# 3    125.5  0.35     2304          Right                       4.0        5.0
#
# ...

# %%
top_value = fifa2.sort_values(by = ['Value'], ascending = False)
plt.figure(figsize = (15, 8))
sns.barplot(x = top_value ["Value"], y = top_value["Name"][:5]);

# %% [markdown]
# ## TOP 10 PLAYERS WITH HIGHEST OVERALL RATINGS

# %%
fifa_overall = fifa2.sort_values(['Overall'],ascending=False)[:10]
fifa_overall[['Name','Overall','Potential','Club','Preferred Foot','Position', 'Nationality']].style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_eb339_row0_col1, #T_eb339_row5_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_eb339_row0_col2, #T_eb339_row6_col2 {
#   background-color: #f14432;
#   color: #f1f1f1;
# }
# #T_eb339_row1_col1 {
#   background-color: #e32f27;
#   color: #f1f1f1;
# }
# #T_eb339_row1_col2, #T_eb339_row9_col2 {
#   background-color: #fc8a6a;
#   color: #f1f1f1;
# }
# #T_eb339_row2_col1, #T_eb339_row3_col1, #T_eb339_row4_col1, #T_eb339_row5_col1, #T_eb339_row6_col1 {
#   background-color: #fca082;
#   color: #000000;
# }
# #T_eb339_row2_col2, #T_eb339_row3_col2, #T_eb339_row4_col2 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_eb339_row7_col1, #T_eb339_row7_col2, #T_eb339_row8_col1, #T_eb339_row8_col2, #T_eb339_row9_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_eb339_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Name</th>
# ...

# %% [markdown]
# These are the top 10 -> <br>
# `L. Messi`,`R. Lewandowski`,`Neymar Jr`,`K. De Bruyne`,`Cristiano Ronaldo`,`K. Mbappé`,`J. Oblak`,`H. Kane`,`M. ter Stegen`,`M. Neuer`<Br>
# Interesting FACT ---->>> 2 German Goalkeepers in the top 10 in `M. ter Stegen` and `M. Neuer`. <Br>
# And also <B>I WONDER HOW PSG IS LOSING SO MANY MATCHES -> 3 OF THEIR BEST ARE IN THE TOP10 TOO </B>

# %% [markdown]
# ## TOP 10 PLAYERS WITH HIGHEST POTENTIAL

# %%
fifa_potential = fifa2.sort_values(['Potential'],ascending=False)[:10]
fifa_potential[['Name','Overall','Potential','Club','Preferred Foot','Position']].style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_2cee0_row0_col1, #T_2cee0_row4_col1 {
#   background-color: #c2161b;
#   color: #f1f1f1;
# }
# #T_2cee0_row0_col2, #T_2cee0_row2_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_2cee0_row1_col1 {
#   background-color: #fb7c5c;
#   color: #f1f1f1;
# }
# #T_2cee0_row1_col2, #T_2cee0_row2_col2, #T_2cee0_row3_col2, #T_2cee0_row4_col2, #T_2cee0_row5_col1, #T_2cee0_row6_col1 {
#   background-color: #fca082;
#   color: #000000;
# }
# #T_2cee0_row3_col1 {
#   background-color: #f6553c;
#   color: #f1f1f1;
# }
# #T_2cee0_row5_col2, #T_2cee0_row6_col2, #T_2cee0_row7_col2, #T_2cee0_row8_col1, #T_2cee0_row8_col2, #T_2cee0_row9_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_2cee0_row7_col1 {
#   background-color: #9d0d14;
#   color: #f1f1f1;
# }
# #T_2cee0_row9_col1 {
#   background-color: #e32f27;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2cee0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %% [markdown]
# These are the top 10:  <br>
# `K. Mbappé`,`E. Haaland`,`L. Messi`,`G. Donnarumma`,`J. Oblak`,`F.de Jong`,`T.Alexander-Arnold`,`R. Lewandowski`,`K. Havertz`,`M. ter Stegen`<Br>

# %% [markdown]
# We've always been viewing the top guys! We will see the bottom ones now.

# %% [markdown]
# ## BOTTOM 10 IN POTENTIAL AND OVERALL

# %%
fifa2.sort_values(['Overall'],ascending=True)[:10]
# Out:
#                   Name  Age          Nationality  Overall  Potential  \
# 15999     16 E. Redman   18                Wales       44         57
# 15593  18 T. Käßemodel   28              Germany       46         46
# 15685   15 T. Fletcher   19              England       46         52
# 16708        A. Shaikh   18                India       47         67
# 15244     R. Gallagher   20  Republic of Ireland       47         61
# 15283     Wang Zhen'ao   21             China PR       47         57
# 14787        Hu Xingyu   19             China PR       47         55
# 14720        N. Saliba   17               Canada       47         69
# 15434        L. Rudden   19  Republic of Ireland       47         60
# 15573     Wang Shilong   20             China PR       47         60
#
#                                     Club  Value   Wage  Special  \
# 15999                     Newport County   0.05  0.002     1089
# 15593                  FC Erzgebirge Aue   0.03  0.002     1174
# ...

# %%
fifa2.sort_values(['Potential'],ascending=True)[:10]
# Out:
#                      Name  Age          Nationality  Overall  Potential  \
# 15593     18 T. Käßemodel   28              Germany       46         46
# 15733        21 M. Wright   33              England       47         47
# 14188          J. Russell   36  Republic of Ireland       49         49
# 15027  19 B. Barry-Murphy   39  Republic of Ireland       49         49
# 14304        Tan Chun Lok   25            Hong Kong       49         51
# 15049           S. Haokip   28                India       51         51
# 16388             Ma Zhen   23             China PR       48         52
# 15685      15 T. Fletcher   19              England       46         52
# 15601       M. McChrystal   37     Northern Ireland       52         52
# 16203            K. Singh   34                India       53         53
#
#                       Club  Value   Wage  Special Preferred Foot  \
# 15593    FC Erzgebirge Aue  0.030  0.002     1174          Right
# ...

# %% [markdown]
# ## Top Rated Players by Nationality
# - ### Nigerian Players

# %%
fifa2Nigeria = fifa2.loc[fifa2.Nationality=='Nigeria']
fifa2Nigeria.sort_values(['Overall'],ascending=False)[:5]
# Out:
#               Name  Age Nationality  Overall  Potential            Club  \
# 218       W. Ndidi   24     Nigeria       85         88  Leicester City
# 1425    V. Osimhen   22     Nigeria       80         87          Napoli
# 3795    P. Onuachu   27     Nigeria       79         80        KRC Genk
# 1826  K. Iheanacho   24     Nigeria       78         82  Leicester City
# 338       V. Moses   30     Nigeria       78         78  Spartak Moskva
#
#       Value   Wage  Special Preferred Foot  International Reputation  \
# 218    66.5  0.120     2113          Right                       1.0
# 1425   43.0  0.066     1961          Right                       2.0
# 3795   20.5  0.023     1841          Right                       1.0
# 1826   20.5  0.083     1934           Left                       1.0
# 338    13.5  0.056     2081          Right                       2.0
#
#       Weak Foot  Skill Moves       Work Rate         Body Type Position  \
# ...

# %% [markdown]
# - ### German Players

# %%
fifa2_Germany = fifa2.loc[fifa2.Nationality=='Germany']

fifa2_Germany.sort_values(['Overall'],ascending=False)[:5]
# Out:
#                 Name  Age Nationality  Overall  Potential               Club  \
# 13890  M. ter Stegen   29     Germany       90         92       FC Barcelona
# 12350       M. Neuer   35     Germany       90         90  FC Bayern München
# 5         J. Kimmich   26     Germany       89         90  FC Bayern München
# 116         T. Kroos   31     Germany       88         88     Real Madrid CF
# 125       17 P. Lahm   32     Germany       88         88  FC Bayern München
#
#        Value   Wage  Special Preferred Foot  International Reputation  \
# 13890   99.0  0.250     1444          Right                       4.0
# 12350   13.5  0.086     1534          Right                       5.0
# 5      108.0  0.160     2283          Right                       4.0
# 116     75.0  0.310     2148          Right                       4.0
# 125     29.5  0.200     2146          Right                       4.0
#
#        Weak Foot  Skill Moves       Work Rate         Body Type Position  \
# ...

# %% [markdown]
# - ### Portuguese players

# %%
fifa2Portugal = fifa2.loc[fifa2.Nationality=='Portugal']
fifa2Portugal.sort_values(['Overall'],ascending=False)[:11]
# Out:
#                     Name  Age Nationality  Overall  Potential  \
# 36     Cristiano Ronaldo   36    Portugal       91         91
# 0        Bruno Fernandes   26    Portugal       88         89
# 2754          Rúben Dias   24    Portugal       87         91
# 170       Bernardo Silva   26    Portugal       86         86
# 21          João Cancelo   27    Portugal       86         87
# 60       Ricardo Pereira   27    Portugal       84         84
# 80          R. Guerreiro   27    Portugal       84         84
# 439          André Silva   25    Portugal       84         85
# 421           João Félix   21    Portugal       83         91
# 14615           A. Lopes   30    Portugal       82         83
# 617             Palhinha   25    Portugal       82         87
#
#                      Club  Value   Wage  Special Preferred Foot  \
# 36      Manchester United   45.0  0.270     2208          Right
# 0       Manchester United  107.5  0.250     2341          Right
# ...

# %% [markdown]
# - ### French Players

# %%
fifa2France = fifa2.loc[fifa2.Nationality=='France']
fifa2France.sort_values(['Overall'],ascending=False)[:11]
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 82         K. Mbappé   22      France       91         95
# 71          N. Kanté   30      France       90         90
# 201       K. Benzema   33      France       89         89
# 27          P. Pogba   28      France       87         87
# 14644      H. Lloris   34      France       87         87
# 1228        K. Coman   25      France       86         87
# 1897       R. Varane   28      France       86         88
# 9       A. Griezmann   30      France       85         85
# 22          L. Digne   27      France       84         84
# 232    W. Ben Yedder   30      France       84         84
# 199         N. Fekir   27      France       84         84
#
#                       Club  Value   Wage  Special Preferred Foot  \
# 82     Paris Saint-Germain  194.0  0.230     2175          Right
# 71                 Chelsea  100.0  0.230     2179          Right
# 201         Real Madrid CF   66.0  0.350     2116          Right
# ...

# %% [markdown]
# - ### English Players

# %%
fifa2France = fifa2.loc[fifa2.Nationality=='England']
fifa2France.sort_values(['Overall'],ascending=False)[:11]
# Out:
#                      Name  Age Nationality  Overall  Potential  \
# 39                H. Kane   27     England       90         90
# 220           R. Sterling   26     England       88         89
# 24    T. Alexander-Arnold   22     England       87         92
# 855             J. Sancho   21     England       87         91
# 154              J. Vardy   34     England       86         86
# 127           M. Rashford   23     England       85         89
# 53              K. Walker   31     England       85         85
# 65            K. Trippier   30     England       84         84
# 444              P. Foden   21     England       84         92
# 167               L. Shaw   25     England       84         86
# 1591           H. Maguire   28     England       84         86
#
#                     Club  Value   Wage  Special Preferred Foot  \
# 39     Tottenham Hotspur  129.5  0.240     2205          Right
# 220      Manchester City  107.5  0.290     2113          Right
# ...

# %% [markdown]
# ### Let's look out for some veterans

# %%
#fifa2.loc[fifa2.Age >38]
fifa_potential = fifa2.sort_values(['Age'],ascending=False)[:11]
fifa_potential[['Name','Age','Overall','Potential','Club','Preferred Foot','Position']].style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_4a730_row0_col1, #T_4a730_row1_col2, #T_4a730_row1_col3 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_4a730_row0_col2, #T_4a730_row0_col3, #T_4a730_row9_col2, #T_4a730_row9_col3 {
#   background-color: #ee3a2c;
#   color: #f1f1f1;
# }
# #T_4a730_row1_col1, #T_4a730_row2_col1 {
#   background-color: #f14432;
#   color: #f1f1f1;
# }
# #T_4a730_row2_col2, #T_4a730_row2_col3 {
#   background-color: #e32f27;
#   color: #f1f1f1;
# }
# #T_4a730_row3_col1, #T_4a730_row4_col1, #T_4a730_row5_col1, #T_4a730_row6_col1, #T_4a730_row7_col1, #T_4a730_row8_col1 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_4a730_row3_col2, #T_4a730_row3_col3 {
#   background-color: #f75b40;
#   color: #f1f1f1;
# }
# #T_4a730_row4_col2, #T_4a730_row4_col3, #T_4a730_row6_col2, #T_4a730_row6_col3 {
#   background-color: #fcae92;
#   color: #000000;
# }
# #T_4a730_row5_col2, #T_4a730_row5_col3, #T_4a730_row9_col1, #T_4a730_row10_col1 {
# ...

# %% [markdown]
# ## The most represented national teams on FIFA22
#
# ### - Word Count and
# ### - Bar Chart

# %%
from wordcloud import WordCloud, STOPWORDS
text = " ".join(nationality for nationality in fifa2.Nationality)
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(text)
plt.figure(figsize = (20, 6))
plt.imshow(word_cloud, interpolation = 'bilinear')
plt.axis("off")
plt.show()

# %%
sns.countplot(x="Nationality", data=fifa2, order=fifa2["Nationality"].value_counts().index[:5]);

# %% [markdown]
# The bar chart above backs up the data

# %% [markdown]
# ### Average age of each national team in FIFA22

# %%
plt.figure(figsize=(12,35))
sns.barplot(y=fifa2['Nationality'],x=fifa2['Age'])
plt.plot()
# Out:
# []

# %% [markdown]
# Average age of players from Oman and Eritrea teams are greater than 35, while Indonesia's is less than 20!!!!!

# %% [markdown]
# ### Players with the highst rated skill moves including with their weak foot

# %%
fifa2.loc[((fifa2['Weak Foot']==fifa2['Weak Foot'].max()) &(fifa2['Skill Moves']==fifa2['Skill Moves'].max()))]
# Out:
#             Name  Age Nationality  Overall  Potential  \
# 64     Neymar Jr   29      Brazil       91         91
# 91     J. Corona   28      Mexico       82         82
# 1026  O. Dembélé   24      France       83         88
# 1129        Nani   34    Portugal       81         81
# 2402     Cesinha   31      Brazil       75         75
# 2882   F. Ribéry   38      France       79         79
# 7644   R. Cherki   17      France       73         88
#
#                           Club  Value   Wage  Special Preferred Foot  \
# 64         Paris Saint-Germain  129.0  0.270     2183          Right
# 91                    FC Porto   30.5  0.022     2167          Right
# 1026              FC Barcelona   55.0  0.165     1990           Left
# 1129  Orlando City Soccer Club   12.0  0.014     1981          Right
# 2402                  Daegu FC    4.7  0.009     1902          Right
# 2882       US Salernitana 1919    6.0  0.041     1880          Right
# ...

# %% [markdown]
# ## `Weak Foot` and `Skill Moves` - NEYMAR, CORONA, DEMBELE, NANI, CESINHA, RIBERY

# %% [markdown]
# ## PLAYER POSITION

# %%
fifa_pos = fifa2['Position'].value_counts()
plt.figure(figsize=(15,5))
sns.barplot(fifa_pos.index,fifa_pos.values)
plt.show()

# %% [markdown]
# No of centre forwards in the player set is the least. We can see how many of them are there in this dataset

# %% [markdown]
# Center Forwards are--

# %%
fifa2.loc[fifa2['Position']=='CF']
# Out:
#                      Name  Age Nationality  Overall  Potential  \
# 68        Roberto Firmino   29      Brazil       85         85
# 201            K. Benzema   33      France       89         89
# 382          L. Rodríguez   36   Argentina       79         79
# 2134             Deulofeu   27       Spain       79         79
# 2515             A. Büyük   33      Turkey       73         73
# 2547              Muriqui   35      Brazil       73         73
# 8386          20 J. Ménez   32      France       70         70
# 9202             H. Mahou   21      France       64         71
# 5564  20 Abraham González   33       Spain       66         66
# 5773             Tan Long   33    China PR       67         67
#
#                                Club   Value   Wage  Special Preferred Foot  \
# 68                        Liverpool  54.000  0.185     2180          Right
# 201                  Real Madrid CF  66.000  0.350     2116          Right
# ...

# %% [markdown]
# # Top 10 Tallest palyers

# %%
data_height = fifa2.sort_values(['Height'],ascending=False)[:10]
data_height[['Name','Height', 'Club','Nationality']]
# Out:
#                    Name Height                   Club     Nationality
# 16176           T. Holý  206cm           Ipswich Town  Czech Republic
# 15358       20 M. Casey  203cm             Portsmouth         England
# 15751  21 C. Pantilimon  203cm            Denizlispor         Romania
# 14577         P. Ndiaye  203cm    SC Rheindorf Altach          France
# 12448      20 L. Traoré  203cm               CFR Cluj   Côte d'Ivoire
# 15678        A. Noppert  203cm        Go Ahead Eagles     Netherlands
# 13126          F. Mulić  203cm            Seongnam FC          Serbia
# 12210  21 S. Maierhofer  202cm  FC Würzburger Kickers         Austria
# 15204        C. Ezekwem  202cm         Sportclub Verl         Germany
# 15760       N. Stojišić  202cm         Vegalta Sendai          Serbia

# %% [markdown]
# ## Top 5 Shortest Players

# %%
height = fifa2.sort_values(['Height'],ascending=True)[:5]
height[['Name','Height', 'Club','Nationality']]
# Out:
#              Name Height                       Club Nationality
# 9791    M. García  155cm  Club Universidad Nacional      Mexico
# 8218     L. Paiva  156cm    Club Atlético Rentistas     Uruguay
# 7245   N. Barrios  156cm     San Lorenzo de Almagro   Argentina
# 2999  21 J. Plata  157cm           Deportivo Toluca     Ecuador
# 2587   Y. Soteldo  158cm                 Toronto FC   Venezuela

# %% [markdown]
# ## HEAVIEST PLAYER

# %%
weight = fifa2.sort_values(['Weight'],ascending=False)[:1]
weight[['Name','Weight','Club','Nationality']]
# Out:
#                Name  Weight               Club Nationality
# 11849  A. Akinfenwa      11  Wycombe Wanderers     England

# %% [markdown]
# ## Potential as related to Age

# %%
sns.jointplot(x=fifa2['Age'],y=fifa2['Potential'],
              joint_kws={'alpha':0.1,'s':5,'color':'red'},
              marginal_kws={'color':'red'})

# %% [markdown]
# As it normally happens, players' potential increases from their young age and begins to decrease towards their retirement age.

# %% [markdown]
# ## POSITION VS PLAYER VALUE

# %%
plt.figure(figsize=(15,8))
sns.barplot(y=fifa2['Value'],x=fifa2['Position'], color = 'b')
plt.plot()
# Out:
# []

# %% [markdown]
# There are exceptions for each position. But what we can see from this is that the forwards mean values are actually at the top compared to all other positions.

# %% [markdown]
# ## AGILITY, AGGRESSION AND THEIR CORRELATIONS

# %%
correlation = fifa2[['Crossing', 'Finishing', 'HeadingAccuracy',
       'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
       'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
       'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
       'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision']]

# %%
plt.figure(figsize=(20,12))
sns.heatmap(round(correlation.corr(),2),annot=True,cmap='Blues')
plt.show()

# %% [markdown]
# Some highly correlated features in the dataset - `Positioning` and `Finishing` ; `Positioning` and `Dribbling`, `positioning` and `finishing`. Infact positioning is a highly correlated feature with many other features as well like - Longshots <br>
# `Ball Control` is highly correlated with `Short Passing` and `Dribbling`
# `Accelaration` is highly correlated with `Sprint Speed`.
#
# Agility is one other feature we would be interested in. We can see that `Agility` is highly correlated with `Balance`, `dribbling`, `Sprintspeed` and `Acceleration`. So you have got an important tip to know a a great footballer.

# %%
correlation.sort_values(['Vision'],ascending=False)[:5]
# Out:
#      Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  \
# 29       85.0       95.0             70.0          91.0     88.0       96.0
# 3        94.0       82.0             55.0          94.0     82.0       88.0
# 244      85.0       74.0             51.0          93.0     66.0       80.0
# 830      69.0       77.0             49.0          92.0     76.0       85.0
# 422      83.0       65.0             72.0          89.0     85.0       75.0
#
#      Curve  FKAccuracy  LongPassing  BallControl  Acceleration  SprintSpeed  \
# 29    93.0        94.0         91.0         96.0          91.0         80.0
# 3     85.0        83.0         93.0         91.0          76.0         76.0
# 244   85.0        87.0         90.0         93.0          67.0         65.0
# 830   86.0        79.0         90.0         91.0          61.0         59.0
# 422   74.0        67.0         90.0         87.0          53.0         53.0
#
# ...

# %% [markdown]
# Players with great `Vision` have better overalls. This is true as vision is a great technical ability which contributes to a good level of:
#
# - Passing Accuracy
# - Free kick accuracy
# - positioning
# - and Finishing.

# %%
correlation.sort_values(['Aggression'],ascending=False)[:5]
# Out:
#        Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  \
# 1040       69.0       63.0             62.0          75.0     62.0       69.0
# 8508       40.0       43.0             67.0          65.0     35.0       50.0
# 2899       52.0       46.0             52.0          72.0     38.0       69.0
# 254        76.0       54.0             77.0          77.0     71.0       71.0
# 13248      60.0       21.0             40.0          56.0     13.0       45.0
#
#        Curve  FKAccuracy  LongPassing  BallControl  Acceleration  SprintSpeed  \
# 1040    67.0        70.0         71.0         75.0          59.0         54.0
# 8508    38.0        57.0         52.0         59.0          34.0         42.0
# 2899    45.0        40.0         71.0         72.0          71.0         70.0
# 254     81.0        77.0         67.0         72.0          77.0         80.0
# 13248   42.0        37.0         55.0         57.0          57.0         54.0
#
# ...

# %% [markdown]
# Aggression is connected with interception and strength.
